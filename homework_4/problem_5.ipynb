# %%
import numpy as np
import matplotlib.pyplot as plt
from homework_functions import example_f, centered_diff, dat_reader, problem_5_solver
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 100

# %%
x,u = problem_5_solver(0,10,1,2, 10,example_f)
exact_x, exact_u = dat_reader('solutionB_N10000.dat')

# %%
plt.plot(x,u, '-o', label = 'N = 10', color = 'red')
plt.plot(exact_x,exact_u, label = 'Exact Solution', color = 'Black')
plt.legend()
plt.xlabel('x')
plt.ylabel('u')
plt.show()

# %%
for xi, ui in zip(x,u):
    print(xi,ui)
# Out:
# 0.0 -3.803910865100113
# 0.09090909090909091 -2.6237467764652695
# 0.18181818181818182 -0.9014363287425566
# 0.2727272727272727 -0.033766063743412955
# 0.36363636363636365 -0.41830288306823094
# 0.4545454545454546 -0.9885707641004653
# 0.5454545454545454 -0.4609425036368191
# 0.6363636363636364 1.1645818983227079
# 0.7272727272727273 2.604375238574819
# 0.8181818181818182 2.7919614945029694
# 0.9090909090909091 2.124907567707551
# 1.0 2.0
