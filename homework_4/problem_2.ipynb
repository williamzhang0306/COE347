# %%
import numpy as np
import matplotlib.pyplot as plt
from homework_functions import example_f, centered_diff, dat_reader
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300

# %%
xi, ui = centered_diff((0,0), (1,2), N = 10**4, f = example_f)
exact_x, exact_u = dat_reader('solutionA_N10000.dat')

# %%
plt.plot(exact_x, exact_u, label = 'Exact Solution', color = 'black')
plt.plot(xi,ui,':', label = 'N = 10^4', color = 'red')

plt.xlabel('x')
plt.ylabel('u')
plt.legend()
plt.show()
